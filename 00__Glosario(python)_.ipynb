# %% [markdown]
# <a href="https://colab.research.google.com/github/cristobalvadell/Pensamiento-computacional/blob/main/00__Glosario(python)_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Glosario
#
# 1. división entera `//`
# >división la cual el resultado entregado seguira siendo entero
#
# ---
#
# 2. Expresión
# >es una coleccion de operaciones y números
#
# ---
#
# 3. Valor
# >es el resultado entregado por una operasión
#
# ---
#
# 4. Error: Syntaxerror
# >ocurre cuando llamo a una funcion y cometo un error en la escritura
# >por ejemplo `abs 42`
